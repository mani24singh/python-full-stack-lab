# %% [markdown]
# ### Importing Modules in Python: Modules and Packages
# - In python, modules and packages help organize and reuse code. Here's a comprehensive guide on how to import them.

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt, pi
print(sqrt(16))
print(sqrt(36))
print(pi)
# Out:
# 4.0
# 6.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %% [markdown]
# #### To create custom package :
# - we create a folder package
# - add init.py file within it to define it as a module
# - create a customized function .py script

# %%
from package.maths import addition

addition(2,4)
# Out:
# 6

# %%
from package import maths
maths.addition(2,3)
# Out:
# 5

# %%
from package.subpackage.mult import multiply
multiply(3,4)
# Out:
# 12

# %% [markdown]
# #### Conclusion
# Importing modules and packages in Python allows you to organize your code, reuse functionalities, and keep your projects clean and manageable. By understanding how to import modules, specific functions, and use relative imports within packages, you can structure your Python applications more effectively.
