# %% [markdown]
# ### Some terminologies for remembering in OOPS
#
# 1. def __init__(self, ...)  -->  this is called as "constructor"
# 2. def selfdriving(self):   --> this is called "instance method"
# 3. Any def function that is directly inside a class  --> called as method
# 4. def with @classmethod  decorator --> "class method"
# 5. def with @staticmethod decorator  --> "static method"
# 6. def with @property decorator  --> "property (or getter method)"

# %% [markdown]
# ### Inheritance in Python
#
# - Inheritance is a fundamental concept in object oriented programming (OOP) that allows a class to inherit attributes and methods from another class. This lesson covers single inheritance and multiple inheritance, demonstrating how to create and use them in python.

# %%
# Inheritance (Single inheritance)

# Parent Class
class Car:
    def __init__(self, windows, doors, enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype

    def drive(self):
        print(f"The person will drive the {self.enginetype} car")

# %%
car1=Car(4,5,"petrol")
car1.drive()
# Out:
# The person will drive the petrol car

# %% [markdown]
# - Note:
#     - super() in Python is a built-in function that gives you access to methods of parent (or more accurately: ancestor) classes in a clean and safe way — especially important when using inheritance (single or multiple).
#     - most common usage: super().method_name(args) or the very frequent pattern in __init__:
#         - class Child(Parent):
#             def __init__(self, ...):
#             super().__init__(...)     # calls Parent.__init__
#
#     - or sometimes: super(Child, self).__init__(...)

# %%
class Tesla(Car):
    def __init__(self, windows, doors, enginetype, is_selfdriving):    # -> constructor
        super().__init__(windows, doors, enginetype)
        self.is_selfdriving=is_selfdriving
    
    def selfdriving(self):     # -> instance method
        print(f"Tesla supports self driving: {self.is_selfdriving}")

# %%
tesla1=Tesla(4,5,"electric",True)
tesla1.selfdriving()
# Out:
# Tesla supports self driving: True

# %%
tesla1.drive()
# Out:
# The person will drive the electric car

# %%
## Multiple Inheritance

# When a class inherits from more than one base class

# Base class 1
class Animal:
    def __init__(self, name):
        self.name=name
    
    def speak(self):
        print("Subclass must implement this method")


# Base class 2
class Pet:
    def __init__(self, owner):
        self.owner=owner


# Derived class 
class Dog(Animal, Pet):
    def __init__(self, name, owner):
        Animal.__init__(self, name)
        Pet.__init__(self, owner)
    
    def speak(self):        
        return f"{self.name} says woof"


# Create an object
dog=Dog("Buddy", "Mani")
print(dog.speak())
print(f"Owner: {dog.owner}")
# Out:
# Buddy says woof
# Owner: Mani

# %% [markdown]
# #### Conclusion
# - Inheritance is a powerful feature in OOP that allows for code reuse and the creation of a more logical class structure. Single inheritance involves one base class, while multiple inheritance involves more than one base class. Understanding how to implement and use inheritance in Python will enable you to design more efficient and maintainable object-oriented programs.
