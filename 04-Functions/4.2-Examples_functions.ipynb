# %% [markdown]
# ### Function Examples

# %% [markdown]
# ### Example 1: Temperature Conversion

# %%
def convert_temperature(temp, unit):
    """This function comnverts temperature
    between Celcius and Fahrenheit"""
    if unit == "C":
        return temp * 9/5 + 32   # celcius to fahrenheit
    elif unit == "F":
        return (temp-32)*5/9  # fahrenheit to celcius
    else:
        return "Invalid unit"
    
print(convert_temperature(100, "C"))  # Expected output: 212.0
print(convert_temperature(212, "F"))  # Expected output: 100.0
# Out:
# 212.0
# 100.0

# %% [markdown]
# ### Example 2: Password Strength Checker

# %%
def is_strong_password(password):
    """This function checks if a password is strong.
    A strong password has at least 8 characters,
    contains both uppercase and lowercase letters,
    and includes at least one digit."""
    if len(password) < 8:
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char in '!@#$%^&*()_+' for char in password):
        return False
    return True


# Calling the Function 
print(is_strong_password("Password123"))  # Expected output: True
print(is_strong_password("WeakPwd"))
print(is_strong_password("Str0ngPwd!"))
# Out:
# False
# False
# True

# %% [markdown]
# ### Example 3: Calculate the Total Cost of items in a shopping cart

# %%
def calculate_total_cost(cart):
    total_cost=0
    for item in cart:
        total_cost += item['price'] * item['quantity']
    return total_cost

## Example cart data
cart = [
    {'name':'Apple','price':0.5,'quantity':4},
    {'name':'Banana','price':0.3,'quantity':6},
    {'name':'Orange','price':0.7,'quantity':3}
]

## Calling the function
total_cost = calculate_total_cost(cart)
print(f"Total cost of the cart is: ${total_cost:.2f}")  # Expected output: Total cost of the cart is: $5.10
# Out:
# Total cost of the cart is: $5.90

# %% [markdown]
# ### Example 4: Check IF a string is Palindrome

# %%
# Palindrome is a sentence/word which returns same when reversed
def is_palindrome(string):
    s = string.lower().replace(" ", "")
    return s==s[::-1]

print(is_palindrome("A man a plan a canal Panama"))
print(is_palindrome("Hello"))
# Out:
# True
# False

# %% [markdown]
# ### Example 5: Calculate the factorials of a number using recursion

# %%
# good example of calling function within the function
def factorial(n):
    if n==0:
        return 1
    else:
        return n * factorial(n-1)
    
print(factorial(6))
print(factorial(5))
print(factorial(12))
# Out:
# 720
# 120
# 479001600

# %% [markdown]
# ### Example 6: A function to read a file and count the frequency of each word

# %%
def count_word_frequency(file_path):
    word_count={}
    with open(file_path, 'r') as file:
        for line in file:
            words = line.split()
            for word in words:
                word = word.lower().strip('.,?!;:\'')
                word_count[word] = word_count.get(word,0)+1     # logic --> dictionary.get(key, default_value) + increment_value
    return word_count

file_path='sample.txt'
word_frequency = count_word_frequency(file_path)
print(word_frequency)
# Out:
# {'hello': 1, 'world': 2, 'how': 1, 'are': 1, 'you': 1, 'my': 1, 'name': 2, 'is': 3, 'mani': 1, 'singh': 1, 'what': 1, 'your': 1, 'a': 1, 'good': 1, 'place': 1}

# %% [markdown]
# ### Example 7: Validate Email Address

# %%
import re    # regrex logic

# Email validation function
def is_valid_email(email):
    """This function checks if the email is valid"""
    pattern = r'^[a-zA-Z0-9.+_-]+@[a-zA-Z0-9-]+\.[a-zA-Z0-9-.]+$'
    return re.match(pattern, email) is not None

# Calling the function
print(is_valid_email("test@example.com"))  # Output: True
print(is_valid_email("invalid-email"))  # Output: False
# Out:
# True
# False

# %% [markdown]
# #### Note: Detailed Regrex pdf beginner guide is added for reference (along with basic interview regrex problems)
